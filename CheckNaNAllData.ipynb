# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/JustinHolmes/Desktop/Staple Health/County/Mental Health Data/Concatenated_Data/US_County_All_Data_71719.csv", skiprows = 0, sep = ',', header = 0, dtype = {'FIPS': 'Int32'})
df.head()
# Out:
#    FIPS    State   County  % with SNAP  Percent Margin of Error (±)  \
# 0  1001  Alabama  Autauga    12.798077                     1.995163
# 1  1003  Alabama  Baldwin     8.898322                     0.972884
# 2  1005  Alabama  Barbour    25.356281                     2.404316
# 3  1007  Alabama     Bibb    14.841090                     2.856595
# 4  1009  Alabama   Blount    11.523353                     1.589438
#
#    Life Expectancy  95% CI - Low_x  95% CI - High_x  Life Expectancy (Black)  \
# 0             76.3            75.6             77.1                     74.6
# 1             78.6            78.2             79.0                     75.6
# 2             75.8            74.6             76.9                     74.2
# 3             73.9            72.6             75.2                     72.3
# 4             74.6            73.8             75.4                      NaN
#
#    Life Expectancy (Hispanic)  ...  95% CI - High.18  Z-Score.34  \
# ...

# %%
df.isna().sum()
# Out:
# FIPS                                       0
# State                                      0
# County                                     0
# % with SNAP                                0
# Percent Margin of Error (±)                0
# Life Expectancy                           69
# 95% CI - Low_x                            69
# 95% CI - High_x                           69
# Life Expectancy (Black)                 1803
# Life Expectancy (Hispanic)              1895
# Life Expectancy (White)                 1416
# # Deaths                                  61
# Age-Adjusted Mortality                    61
# 95% CI - Low.1_x                          61
# 95% CI - High.1_x                         61
# Age-Adjusted Mortality (Black)          1789
# Age-Adjusted Mortality (Hispanic)       2304
# Age-Adjusted Mortality (White)          1561
# # Deaths.1                              1222
# Child Mortality Rate                    1222
# 95% CI - Low.2_x                        1222
# ...
